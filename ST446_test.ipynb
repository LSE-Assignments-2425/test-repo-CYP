# %%
import pandas as pd

# %%
fire = pd.read_csv(r'D:\LSE_Graduate\WT\ST446\final_project\data\cci_merged.csv')
display(fire.head())
print(fire.shape)
# Out:
#                                                                             year  \
# 2003 {\geodesic\":false \"type\":\"Point\"  \"coordinates\":[-118.74380583133896
# 2011 {\geodesic\":false \"type\":\"Point\"  \"coordinates\":[-118.63600799724462
# 2015 {\geodesic\":false \"type\":\"Point\"  \"coordinates\":[-119.73195264387043
#                         \"type\":\"Point\"  \"coordinates\":[-119.77686840807641
# 2018 {\geodesic\":false \"type\":\"Point\"   \"coordinates\":[-118.8516036654333
#
#                                                               geo  \
# 2003 {\geodesic\":false \"type\":\"Point\"   34.76929307184608]}"
# 2011 {\geodesic\":false \"type\":\"Point\"   36.28744590200807]}"
# 2015 {\geodesic\":false \"type\":\"Point\"   38.57814987651285]}"
#                         \"type\":\"Point\"  38.596116182195246]}"
# 2018 {\geodesic\":false \"type\":\"Point\"   34.20335444285078]}"
#
#                                             BurnDate_cci  ConfidenceLevel_cci  \
# ...

# %%
non_fire = pd.read_csv(r'D:\LSE_Graduate\WT\ST446\final_project\data\nonfire_sample_100k.csv')
display(non_fire.head())
print(non_fire.shape)
# Out:
#                                                                             year  \
# 2001 {\geodesic\":false \"type\":\"Point\"  \"coordinates\":[-115.71648332385617
#                         \"type\":\"Point\"  \"coordinates\":[-115.87818007499769
#                         \"type\":\"Point\"   \"coordinates\":[-116.0039442147744
#                         \"type\":\"Point\"    \"coordinates\":[-116.030893673298
#                         \"type\":\"Point\"  \"coordinates\":[-116.17462411875712
#
#                                                               geo  \
# 2001 {\geodesic\":false \"type\":\"Point\"    35.2992990894766]}"
#                         \"type\":\"Point\"  35.335231700841376]}"
#                         \"type\":\"Point\"  35.452012687776914]}"
#                         \"type\":\"Point\"   33.67334842522026]}"
#                         \"type\":\"Point\"  35.308282242317794]}"
#
#                                             precipitation_precip  \
# ...

# %%
all_points = pd.read_csv(r'D:\LSE_Graduate\WT\ST446\final_project\data\firms_merged.csv')
display(all_points.head())
print(all_points.shape)
# Out:
#                                                                             year  \
# 2001 {\geodesic\":false \"type\":\"Point\"   \"coordinates\":[-119.0312667222572
#                         \"type\":\"Point\"   \"coordinates\":[-121.0884087228909
#                         \"type\":\"Point\"  \"coordinates\":[-121.20518970982644
#                         \"type\":\"Point\"   \"coordinates\":[-121.4657011422211
#                         \"type\":\"Point\"  \"coordinates\":[-121.58248212915665
#
#                                                               geo  T21_firms  \
# 2001 {\geodesic\":false \"type\":\"Point\"  36.754569849750226]}"      323.4
#                         \"type\":\"Point\"   37.80559873217006]}"      328.0
#                         \"type\":\"Point\"   37.84153134353485]}"      313.7
#                         \"type\":\"Point\"   39.72799344018584]}"      347.1
#                         \"type\":\"Point\"    38.6679814049248]}"      323.9
#
# ...
